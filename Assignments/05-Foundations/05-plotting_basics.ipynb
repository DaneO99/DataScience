# %% [markdown]
# # 📈 05 - Plotting Basics
#
# Visualization is a core part of data science.
# In this notebook you will learn:
# - Setting up Matplotlib for inline plotting
# - Creating simple line, scatter, and bar plots
# - Customizing titles, labels, and legends
# - Why visuals matter in data storytelling

# %% [markdown]
# ## 1. Setup

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## 2. Line Plot

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label="sin(x)")
plt.title("Line Plot Example")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.legend()
plt.show()

# %%
x1 = np.linspace(0, 10, 100)
y1 = np.sin(x1)

x2 = np.linspace(0, 10, 100)
y2 = np.cos(x2)

plt.plot(x1, y1, label="sin(x)")
plt.plot(x2, y2, label="cos(x)")
plt.title("Line Plot Example")
plt.xlabel("x")
plt.ylabel("sin(x) vs cos(9)")
plt.legend()
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Plot `cos(x)` on the same graph with a different color and label.

# %% [markdown]
# ## 3. Scatter Plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 300 * np.random.rand(50)
colors = np.random.rand(50)

plt.scatter(x, y, s=sizes, c=colors, alpha=0.6, cmap='viridis')
plt.title("Scatter Plot Example")
plt.xlabel("x")
plt.ylabel("y")
plt.colorbar(label="color scale")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 300 * np.random.rand(50)
colors = np.random.rand(50)

#set 1
x1 = np.random.rand(30)
y1 = np.random.rand(30)
sizes1 = 300 * np.random.rand(30)
colors1 = np.random.rand(30)

#set 2
x2 = np.random.rand(20)
y2 = np.random.rand(20)
sizes2 = 300 * np.random.rand(20)
colors2 = np.random.rand(20)
plt.scatter(x, y, s=sizes, c=colors, alpha=0.6, cmap='viridis')
plt.scatter(x1, y1, s=sizes1, c=colors1, alpha=0.6, cmap='viridis')
plt.scatter(x2, y2, s=sizes2, c=colors2, alpha=0.6, cmap='viridis')
plt.title("Scatter Plot Example with My 2 sets")
plt.xlabel("x")
plt.ylabel("y")
plt.colorbar(label="color scale")
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Generate two sets of random points and plot them in different colors on the same scatter plot.

# %% [markdown]
# ## 4. Bar Plot

# %%
categories = ["A", "B", "C", "D"]
values = [5, 7, 3, 8]

plt.bar(categories, values)
plt.title("Bar Plot Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %%
categories = ["Golf", "Movies","Video Games","Work"]
values = [2,4,6,8]
plt.bar(categories,values)
plt.title("Time spent for each activity")
plt.xlabel("Activity")
plt.ylabel("Time (hours)")
# Out:
# Text(0, 0.5, 'Time (hours)')

# %% [markdown]
# ✅ **Your Turn**: Create your own bar chart with at least 4 categories (e.g., favorite foods, courses, or hobbies).

# %% [markdown]
# ## 5. Customizing Plots

# %%
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label="sin(x)", linestyle="--", color="blue")
plt.plot(x, y2, label="cos(x)", linestyle=":", color="red")
plt.title("Customized Line Plot")
plt.xlabel("x (radians)")
plt.ylabel("value")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ✅ **Your Turn**: Customize your own plot with labels, legend, and grid lines.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(50)
y = np.random.rand(50)
sizes = 30 * np.random.rand(50)
colors = np.random.rand(50)
randomnum = np.random.rand(1)

plt.scatter(x, y, s=sizes, c=colors, alpha=.75, cmap='viridis')
plt.title("Customized Scatter Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.colorbar(label="color scale")
plt.show()

# %% [markdown]
# ---
# ### Summary
# - `%matplotlib inline` makes plots display inside the notebook.
# - Line, scatter, and bar plots are the most common basics.
# - Titles, labels, legends, and grids improve readability.
# - Visuals tell stories about data more effectively than raw numbers.
